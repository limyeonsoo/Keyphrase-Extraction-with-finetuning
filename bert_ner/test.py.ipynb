# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from model_test import Net
from data_load import NerDataset, pad, VOCAB, tokenizer, tag2idx, idx2tag
import os
import numpy as np
import argparse

def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("temp", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])

    num_proposed = len(y_pred[y_pred>1])
    num_correct = (np.logical_and(y_true==y_pred, y_true>1)).astype(np.int).sum()
    num_gold = len(y_true[y_true>1])

    print(f"num_proposed:{num_proposed}")
    print(f"num_correct:{num_correct}")
    print(f"num_gold:{num_gold}")
    try:
        precision = num_correct / num_proposed
    except ZeroDivisionError:
        precision = 1.0

    try:
        recall = num_correct / num_gold
    except ZeroDivisionError:
        recall = 1.0

    try:
        f1 = 2*precision*recall / (precision + recall)
    except ZeroDivisionError:
        if precision*recall==0:
            f1=1.0
        else:
            f1=0

    os.remove("temp")

    print("precision=%.2f"%precision)
    print("recall=%.2f"%recall)
    print("f1=%.2f"%f1)
    return precision, recall, f1

class Arg():
    def __init__(self, check_path):
        self.testset = "/home/cilab/LabMembers/YS/WWW/finetuning/test.txt"
        self.checkpoint = check_path
        self.batch_size = 8
  
        
import glob
check_lists=[]
check_list = glob.glob("/home/cilab/LabMembers/YS/bert_ner/finetuned_by_WWW/*.pt")
check_len = len(check_list)
for i in range(1,check_len+1):
    check_lists.append("/home/cilab/LabMembers/YS/bert_ner/finetuned_by_WWW/{}.pt".format(i))

if __name__=="__main__":
    print("load check point of model...")
    
    print(checkpoint.keys())
    model = Net(False, len(VOCAB), 'cpu', False)
    eval_dataset = NerDataset(hp.testset)
    eval_iter = data.DataLoader(dataset=eval_dataset,
                                     batch_size=hp.batch_size,
                                     shuffle=False,
                                     num_workers=4,
                                     collate_fn=pad)
    max_f1 = 0
    max_pt = ""
    f1_list = []
    for check in check_lists:
        print("\nCheck Point : ",check)
        hp = Arg(check)
        checkpoint = torch.load(hp.checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'],strict=False)

        precision, recall, f1 = eval(model, eval_iter)
        f1_list.append(format(f1, '.2f'))
        if max_f1<f1:
            max_f1 = f1
            max_pt = check
    print("\n\n{} : F1_Score : {}".format(max_pt.split('/')[-1], max_f1))
    print(f1_list)
# Out:
# load check point of model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-281a874b137b> in <module>
#      88     print("load check point of model...")
#      89
# ---> 90     print(checkpoint.keys())
#      91     model = Net(False, len(VOCAB), 'cpu', False)
#      92     eval_dataset = NerDataset(hp.testset)
#
# NameError: name 'checkpoint' is not defined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from model_test import Net
from data_load import NerDataset, pad, VOCAB, tokenizer, tag2idx, idx2tag
import os
import numpy as np
import argparse

def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("temp", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])

    num_proposed = len(y_pred[y_pred>1])
    num_correct = (np.logical_and(y_true==y_pred, y_true>1)).astype(np.int).sum()
    num_gold = len(y_true[y_true>1])

    print(f"num_proposed:{num_proposed}")
    print(f"num_correct:{num_correct}")
    print(f"num_gold:{num_gold}")
    try:
        precision = num_correct / num_proposed
    except ZeroDivisionError:
        precision = 1.0

    try:
        recall = num_correct / num_gold
    except ZeroDivisionError:
        recall = 1.0

    try:
        f1 = 2*precision*recall / (precision + recall)
    except ZeroDivisionError:
        if precision*recall==0:
            f1=1.0
        else:
            f1=0

    os.remove("temp")

    print("precision=%.2f"%precision)
    print("recall=%.2f"%recall)
    print("f1=%.2f"%f1)
    return precision, recall, f1

class Arg():
    def __init__(self, check_path):
        self.testset = "/home/cilab/LabMembers/YS/KDD/finetuning/test.txt"
        self.checkpoint = check_path
        self.batch_size = 8
  
        
import glob
check_lists=[]
check_list = glob.glob("/home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/*.pt")
check_len = len(check_list)
for i in range(1,check_len+1):
    check_lists.append("/home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/{}.pt".format(i))

if __name__=="__main__":
    print("load check point of model...")
    
    print(checkpoint.keys())
    model = Net(False, len(VOCAB), 'cpu', False)
    eval_dataset = NerDataset(hp.testset)
    eval_iter = data.DataLoader(dataset=eval_dataset,
                                     batch_size=hp.batch_size,
                                     shuffle=False,
                                     num_workers=4,
                                     collate_fn=pad)
    max_f1 = 0
    max_pt = ""
    f1_list = []
    for check in check_lists:
        print("\nCheck Point : ",check)
        hp = Arg(check)
        checkpoint = torch.load(hp.checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'],strict=False)

        precision, recall, f1 = eval(model, eval_iter)
        f1_list.append(format(f1, '.2f'))
        if max_f1<f1:
            max_f1 = f1
            max_pt = check
    print("\n\n{} : F1_Score : {}".format(max_pt.split('/')[-1], max_f1))
    print(f1_list)
# Out:
# load check point of model...
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict'])
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/1.pt
# num_proposed:411
# num_correct:225
# num_gold:1121
# precision=0.55
# recall=0.20
# f1=0.29
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/2.pt
# num_proposed:779
# num_correct:387
# num_gold:1121
# precision=0.50
# recall=0.35
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/3.pt
# num_proposed:799
# num_correct:363
# num_gold:1121
# precision=0.45
# recall=0.32
# f1=0.38
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/4.pt
# num_proposed:674
# num_correct:318
# num_gold:1121
# precision=0.47
# recall=0.28
# f1=0.35
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/5.pt
# num_proposed:941
# num_correct:417
# num_gold:1121
# precision=0.44
# recall=0.37
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/6.pt
# num_proposed:1024
# num_correct:426
# num_gold:1121
# precision=0.42
# recall=0.38
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/7.pt
# num_proposed:984
# num_correct:438
# num_gold:1121
# precision=0.45
# recall=0.39
# f1=0.42
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/8.pt
# num_proposed:1051
# num_correct:448
# num_gold:1121
# precision=0.43
# recall=0.40
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/9.pt
# num_proposed:911
# num_correct:412
# num_gold:1121
# precision=0.45
# recall=0.37
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/10.pt
# num_proposed:822
# num_correct:383
# num_gold:1121
# precision=0.47
# recall=0.34
# f1=0.39
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/11.pt
# num_proposed:981
# num_correct:440
# num_gold:1121
# precision=0.45
# recall=0.39
# f1=0.42
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/12.pt
# num_proposed:975
# num_correct:430
# num_gold:1121
# precision=0.44
# recall=0.38
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/13.pt
# num_proposed:1312
# num_correct:518
# num_gold:1121
# precision=0.39
# recall=0.46
# f1=0.43
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/14.pt
# num_proposed:1019
# num_correct:437
# num_gold:1121
# precision=0.43
# recall=0.39
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/15.pt
# num_proposed:657
# num_correct:322
# num_gold:1121
# precision=0.49
# recall=0.29
# f1=0.36
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/16.pt
# num_proposed:748
# num_correct:345
# num_gold:1121
# precision=0.46
# recall=0.31
# f1=0.37
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/17.pt
# num_proposed:771
# num_correct:364
# num_gold:1121
# precision=0.47
# recall=0.32
# f1=0.38
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/18.pt
# num_proposed:879
# num_correct:415
# num_gold:1121
# precision=0.47
# recall=0.37
# f1=0.42
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/19.pt
# num_proposed:1061
# num_correct:465
# num_gold:1121
# precision=0.44
# recall=0.41
# f1=0.43
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/20.pt
# num_proposed:759
# num_correct:364
# num_gold:1121
# precision=0.48
# recall=0.32
# f1=0.39
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/21.pt
# num_proposed:841
# num_correct:397
# num_gold:1121
# precision=0.47
# recall=0.35
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/22.pt
# num_proposed:846
# num_correct:403
# num_gold:1121
# precision=0.48
# recall=0.36
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/23.pt
# num_proposed:903
# num_correct:426
# num_gold:1121
# precision=0.47
# recall=0.38
# f1=0.42
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/24.pt
# num_proposed:788
# num_correct:377
# num_gold:1121
# precision=0.48
# recall=0.34
# f1=0.39
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/25.pt
# num_proposed:835
# num_correct:370
# num_gold:1121
# precision=0.44
# recall=0.33
# f1=0.38
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/26.pt
# num_proposed:799
# num_correct:384
# num_gold:1121
# precision=0.48
# recall=0.34
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/27.pt
# num_proposed:720
# num_correct:342
# num_gold:1121
# precision=0.47
# recall=0.31
# f1=0.37
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/28.pt
# num_proposed:912
# num_correct:414
# num_gold:1121
# precision=0.45
# recall=0.37
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/29.pt
# num_proposed:836
# num_correct:400
# num_gold:1121
# precision=0.48
# recall=0.36
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/30.pt
# num_proposed:1078
# num_correct:484
# num_gold:1121
# precision=0.45
# recall=0.43
# f1=0.44
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/31.pt
# num_proposed:862
# num_correct:394
# num_gold:1121
# precision=0.46
# recall=0.35
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/32.pt
# num_proposed:819
# num_correct:373
# num_gold:1121
# precision=0.46
# recall=0.33
# f1=0.38
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/33.pt
# num_proposed:837
# num_correct:392
# num_gold:1121
# precision=0.47
# recall=0.35
# f1=0.40
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/34.pt
# num_proposed:744
# num_correct:357
# num_gold:1121
# precision=0.48
# recall=0.32
# f1=0.38
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/35.pt
# num_proposed:886
# num_correct:394
# num_gold:1121
# precision=0.44
# recall=0.35
# f1=0.39
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/36.pt
# num_proposed:759
# num_correct:365
# num_gold:1121
# precision=0.48
# recall=0.33
# f1=0.39
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/37.pt
# num_proposed:891
# num_correct:408
# num_gold:1121
# precision=0.46
# recall=0.36
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/38.pt
# num_proposed:928
# num_correct:383
# num_gold:1121
# precision=0.41
# recall=0.34
# f1=0.37
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/39.pt
# num_proposed:858
# num_correct:405
# num_gold:1121
# precision=0.47
# recall=0.36
# f1=0.41
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/finetuned_by_KDD/40.pt
# num_proposed:843
# num_correct:389
# num_gold:1121
# precision=0.46
# recall=0.35
# f1=0.40
#
#
# 30.pt : F1_Score : 0.440200090950432
# ['0.29', '0.41', '0.38', '0.35', '0.40', '0.40', '0.42', '0.41', '0.41', '0.39', '0.42', '0.41', '0.43', '0.41', '0.36', '0.37', '0.38', '0.42', '0.43', '0.39', '0.40', '0.41', '0.42', '0.39', '0.38', '0.40', '0.37', '0.41', '0.41', '0.44', '0.40', '0.38', '0.40', '0.38', '0.39', '0.39', '0.41', '0.37', '0.41', '0.40']

# %% [markdown]
# ## kp20k 20% (pre-trained)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from model_test import Net
from data_load import NerDataset, pad, VOCAB, tokenizer, tag2idx, idx2tag
import os
import numpy as np
import argparse

def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("temp", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])

    num_proposed = len(y_pred[y_pred>1])
    num_correct = (np.logical_and(y_true==y_pred, y_true>1)).astype(np.int).sum()
    num_gold = len(y_true[y_true>1])

    print(f"num_proposed:{num_proposed}")
    print(f"num_correct:{num_correct}")
    print(f"num_gold:{num_gold}")
    try:
        precision = num_correct / num_proposed
    except ZeroDivisionError:
        precision = 1.0

    try:
        recall = num_correct / num_gold
    except ZeroDivisionError:
        recall = 1.0

    try:
        f1 = 2*precision*recall / (precision + recall)
    except ZeroDivisionError:
        if precision*recall==0:
            f1=1.0
        else:
            f1=0

    os.remove("temp")

    print("precision=%.2f"%precision)
    print("recall=%.2f"%recall)
    print("f1=%.2f"%f1)
    return precision, recall, f1

class Arg():
    def __init__(self, check_path):
        self.testset = "/home/cilab/LabMembers/YS/WWW/finetuning/test.txt"
        self.checkpoint = check_path
        self.batch_size = 8
  
        
import glob
check_lists=[]
check_list = glob.glob("/home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/*.pt")
check_len = len(check_list)
for i in range(1,check_len+1):
    check_lists.append("/home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/{}.pt".format(i))

if __name__=="__main__":
    print("load check point of model...")
    testset = "/home/cilab/LabMembers/YS/WWW/finetuning/test.txt"
    
    
    model = Net(False, len(VOCAB), 'cpu', False)
    eval_dataset = NerDataset(testset)
    eval_iter = data.DataLoader(dataset=eval_dataset,
                                     batch_size=8,
                                     shuffle=False,
                                     num_workers=4,
                                     collate_fn=pad)
    max_f1 = 0
    max_pt = ""
    f1_list = []
    for check in check_lists:
        print("\nCheck Point : ",check)
        hp = Arg(check)
        checkpoint = torch.load(hp.checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'],strict=False)

        precision, recall, f1 = eval(model, eval_iter)
        f1_list.append(format(f1, '.2f'))
        if max_f1<f1:
            max_f1 = f1
            max_pt = check
    print("\n\n{} : F1_Score : {}".format(max_pt.split('/')[-1], max_f1))
    print(f1_list)
# Out:
# load check point of model...
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/1.pt
# num_proposed:8399
# num_correct:330
# num_gold:1738
# precision=0.04
# recall=0.19
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/2.pt
# num_proposed:7168
# num_correct:271
# num_gold:1738
# precision=0.04
# recall=0.16
# f1=0.06
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/3.pt
# num_proposed:7006
# num_correct:270
# num_gold:1738
# precision=0.04
# recall=0.16
# f1=0.06
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/4.pt
# num_proposed:7394
# num_correct:303
# num_gold:1738
# precision=0.04
# recall=0.17
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/5.pt
# num_proposed:7068
# num_correct:304
# num_gold:1738
# precision=0.04
# recall=0.17
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/6.pt
# num_proposed:8585
# num_correct:354
# num_gold:1738
# precision=0.04
# recall=0.20
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/7.pt
# num_proposed:7945
# num_correct:339
# num_gold:1738
# precision=0.04
# recall=0.20
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/8.pt
# num_proposed:8566
# num_correct:372
# num_gold:1738
# precision=0.04
# recall=0.21
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/9.pt
# num_proposed:8899
# num_correct:376
# num_gold:1738
# precision=0.04
# recall=0.22
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/10.pt
# num_proposed:9141
# num_correct:386
# num_gold:1738
# precision=0.04
# recall=0.22
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/11.pt
# num_proposed:9786
# num_correct:411
# num_gold:1738
# precision=0.04
# recall=0.24
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/12.pt
# num_proposed:9377
# num_correct:388
# num_gold:1738
# precision=0.04
# recall=0.22
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/13.pt
# num_proposed:9453
# num_correct:411
# num_gold:1738
# precision=0.04
# recall=0.24
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/14.pt
# num_proposed:9910
# num_correct:427
# num_gold:1738
# precision=0.04
# recall=0.25
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/15.pt
# num_proposed:9741
# num_correct:417
# num_gold:1738
# precision=0.04
# recall=0.24
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/16.pt
# num_proposed:10127
# num_correct:425
# num_gold:1738
# precision=0.04
# recall=0.24
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/17.pt
# num_proposed:9946
# num_correct:415
# num_gold:1738
# precision=0.04
# recall=0.24
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/18.pt
# num_proposed:10507
# num_correct:435
# num_gold:1738
# precision=0.04
# recall=0.25
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/19.pt
# num_proposed:10524
# num_correct:434
# num_gold:1738
# precision=0.04
# recall=0.25
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/20.pt
# num_proposed:10648
# num_correct:436
# num_gold:1738
# precision=0.04
# recall=0.25
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/21.pt
# num_proposed:10646
# num_correct:446
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/22.pt
# num_proposed:10663
# num_correct:444
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/23.pt
# num_proposed:10682
# num_correct:430
# num_gold:1738
# precision=0.04
# recall=0.25
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/24.pt
# num_proposed:11072
# num_correct:448
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/25.pt
# num_proposed:10997
# num_correct:447
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/26.pt
# num_proposed:11266
# num_correct:462
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/27.pt
# num_proposed:10993
# num_correct:452
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/28.pt
# num_proposed:11334
# num_correct:472
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/29.pt
# num_proposed:11101
# num_correct:465
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/30.pt
# num_proposed:10928
# num_correct:445
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/31.pt
# num_proposed:10961
# num_correct:446
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/32.pt
# num_proposed:11372
# num_correct:467
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/33.pt
# num_proposed:11526
# num_correct:466
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/34.pt
# num_proposed:11617
# num_correct:475
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/35.pt
# num_proposed:11635
# num_correct:478
# num_gold:1738
# precision=0.04
# recall=0.28
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/36.pt
# num_proposed:11181
# num_correct:464
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/37.pt
# num_proposed:11391
# num_correct:471
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/38.pt
# num_proposed:11531
# num_correct:469
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/39.pt
# num_proposed:11632
# num_correct:467
# num_gold:1738
# precision=0.04
# recall=0.27
# f1=0.07
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/40.pt
# num_proposed:11323
# num_correct:454
# num_gold:1738
# precision=0.04
# recall=0.26
# f1=0.07
#
#
# 13.pt : F1_Score : 0.07345188097578412
# ['0.07', '0.06', '0.06', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07', '0.07']

# %% [markdown]
# ## kp20k 20% (pre-trained) WWW

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils import data
from model_test import Net
from data_load import NerDataset, pad, VOCAB, tokenizer, tag2idx, idx2tag
import os
import numpy as np
import argparse

def eval(model, iterator):
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch

            _, _, y_hat = model(x, y)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open("temp", 'w') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    ## calc metric
    y_true =  np.array([tag2idx[line.split()[1]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])
    y_pred =  np.array([tag2idx[line.split()[2]] for line in open("temp", 'r').read().splitlines() if len(line) > 0])

    num_proposed = len(y_pred[y_pred>1])
    num_correct = (np.logical_and(y_true==y_pred, y_true>1)).astype(np.int).sum()
    num_gold = len(y_true[y_true>1])

    print(f"num_proposed:{num_proposed}")
    print(f"num_correct:{num_correct}")
    print(f"num_gold:{num_gold}")
    try:
        precision = num_correct / num_proposed
    except ZeroDivisionError:
        precision = 1.0

    try:
        recall = num_correct / num_gold
    except ZeroDivisionError:
        recall = 1.0

    try:
        f1 = 2*precision*recall / (precision + recall)
    except ZeroDivisionError:
        if precision*recall==0:
            f1=1.0
        else:
            f1=0

    os.remove("temp")

    print("precision=%.2f"%precision)
    print("recall=%.2f"%recall)
    print("f1=%.2f"%f1)
    return precision, recall, f1

class Arg():
    def __init__(self, check_path):
        self.testset = "/home/cilab/LabMembers/YS/KDD/finetuning/test.txt"
        self.checkpoint = check_path
        self.batch_size = 8
  
        
import glob
check_lists=[]
check_list = glob.glob("/home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/*.pt")
check_len = len(check_list)
for i in range(1,check_len+1):
    check_lists.append("/home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/{}.pt".format(i))

if __name__=="__main__":
    print("load check point of model...")
    #testset = "/home/cilab/LabMembers/YS/KDD/finetuning/test.txt"
    testset = "/home/cilab/LabMembers/YS/kp20k/finetuning/valid_40.txt"
    
    model = Net(False, len(VOCAB), 'cpu', False)
    eval_dataset = NerDataset(testset)
    eval_iter = data.DataLoader(dataset=eval_dataset,
                                     batch_size=8,
                                     shuffle=False,
                                     num_workers=4,
                                     collate_fn=pad)
    max_f1 = 0
    max_pt = ""
    f1_list = []
    for check in check_lists:
        print("\nCheck Point : ",check)
        hp = Arg(check)
        checkpoint = torch.load(hp.checkpoint)
        model.load_state_dict(checkpoint['model_state_dict'],strict=False)

        precision, recall, f1 = eval(model, eval_iter)
        f1_list.append(format(f1, '.2f'))
        if max_f1<f1:
            max_f1 = f1
            max_pt = check
    print("\n\n{} : F1_Score : {}".format(max_pt.split('/')[-1], max_f1))
    print(f1_list)
# Out:
# load check point of model...
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/1.pt
# num_proposed:3202617
# num_correct:105395
# num_gold:563559
# precision=0.03
# recall=0.19
# f1=0.06
#
# Check Point :  /home/cilab/LabMembers/YS/bert_ner/new_new_new_model_by_kp40/2.pt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ef072e19d680> in <module>
#     106         model.load_state_dict(checkpoint['model_state_dict'],strict=False)
#     107
# --> 108         precision, recall, f1 = eval(model, eval_iter)
#     109         f1_list.append(format(f1, '.2f'))
#     110         if max_f1<f1:
#
# <ipython-input-9-ef072e19d680> in eval(model, iterator)
#      17             words, x, is_heads, tags, y, seqlens = batch
#      18
# ---> 19             _, _, y_hat = model(x, y)  # y_hat: (N, T)
#      20
#      21             Words.extend(words)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/LabMembers/YS/bert_ner/model_test.py in forward(self, x, y)
#      36             self.bert.eval()
#      37             with torch.no_grad():
# ---> 38                 encoded_layers, _ = self.bert(x)
#      39                 enc = encoded_layers[-1]
#      40
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert-0.6.2-py3.6.egg/pytorch_pretrained_bert/modeling.py in forward(self, input_ids, token_type_ids, attention_mask, output_all_encoded_layers, head_mask)
#     879                                       extended_attention_mask,
#     880                                       output_all_encoded_layers=output_all_encoded_layers,
# --> 881                                       head_mask=head_mask)
#     882         if self.output_attentions:
#     883             all_attentions, encoded_layers = encoded_layers
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert-0.6.2-py3.6.egg/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states, attention_mask, output_all_encoded_layers, head_mask)
#     496         all_attentions = []
#     497         for i, layer_module in enumerate(self.layer):
# --> 498             hidden_states = layer_module(hidden_states, attention_mask, head_mask[i])
#     499             if self.output_attentions:
#     500                 attentions, hidden_states = hidden_states
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert-0.6.2-py3.6.egg/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states, attention_mask, head_mask)
#     477         if self.output_attentions:
#     478             attentions, attention_output = attention_output
# --> 479         intermediate_output = self.intermediate(attention_output)
#     480         layer_output = self.output(intermediate_output, attention_output)
#     481         if self.output_attentions:
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert-0.6.2-py3.6.egg/pytorch_pretrained_bert/modeling.py in forward(self, hidden_states)
#     446     def forward(self, hidden_states):
#     447         hidden_states = self.dense(hidden_states)
# --> 448         hidden_states = self.intermediate_act_fn(hidden_states)
#     449         return hidden_states
#     450
#
# /usr/local/lib/python3.6/dist-packages/pytorch_pretrained_bert-0.6.2-py3.6.egg/pytorch_pretrained_bert/modeling.py in gelu(x)
#     165         Also see https://arxiv.org/abs/1606.08415
#     166     """
# --> 167     return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))
#     168
#     169
#
# KeyboardInterrupt:
